# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\\adefe\\Documents\\DataScienceProjects\\OnlineProjects\\Analytics XYZ") 
#Current working directory that contains your dataset and code file

# %%
extension = 'csv'
all_branches = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_branches])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# set new csv file to variable name 'combined'.

# %%
pd.read_csv("combined_csv.csv")
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 2995  148-41-7930      C  Port Harcourt        Normal    Male
# 2996  189-40-5216      C  Port Harcourt        Normal    Male
# 2997  267-62-7380      C  Port Harcourt        Member    Male
# 2998  652-49-6720      C  Port Harcourt        Member  Female
# 2999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
import pandas as np
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
combined = pd.read_csv('combined_csv.csv')

# %%
combined.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
combined.shape
# Used to know the amount of rows and columns used
# Out:
# (3000, 17)

# %%
for col in combined:
    print(col)
# Out:
# Invoice ID
# Branch
# City
# Customer type
# Gender
# Product line
# Unit price
# Quantity
# Tax 5%
# Total
# Date
# Time
# Payment
# cogs
# gross margin percentage
# gross income
# Rating

# %%
combined.describe()
# Used to describe the dataset
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   3000.000000  3000.000000   3000.000000    3000.000000    3000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9534.885259     2.922456   4213.771411   88489.199635   84275.428224
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income       Rating
# count             3.000000e+03   3000.000000  3000.000000
# mean              4.761905e+00   5536.572840     6.972700
# std               3.109143e-13   4213.771411     1.718007
# ...

# %% [markdown]
# The mean per unit price is approximately 20042, quantity 5.51gross income 5536.
# <br>
# The standard deviation (std) of unit price: 9535.680197, quantity: 2.922699, gross income: 4214.12272.
# <br>
# The gross margin column is missing as their values are not substantial enough to be displayed.

# %%
combined.isnull().sum()
# Used to test for missing values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
combined.notna().sum()
# Used to discover non missing variables
# Out:
# Invoice ID                 3000
# Branch                     3000
# City                       3000
# Customer type              3000
# Gender                     3000
# Product line               3000
# Unit price                 3000
# Quantity                   3000
# Tax 5%                     3000
# Total                      3000
# Date                       3000
# Time                       3000
# Payment                    3000
# cogs                       3000
# gross margin percentage    3000
# gross income               3000
# Rating                     3000
# dtype: int64

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               3000 non-null   object
#  1   Branch                   3000 non-null   object
#  2   City                     3000 non-null   object
#  3   Customer type            3000 non-null   object
#  4   Gender                   3000 non-null   object
#  5   Product line             3000 non-null   object
#  6   Unit price               3000 non-null   float64
#  7   Quantity                 3000 non-null   int64
#  8   Tax 5%                   3000 non-null   float64
#  9   Total                    3000 non-null   float64
#  10  Date                     3000 non-null   object
#  11  Time                     3000 non-null   object
#  12  Payment                  3000 non-null   object
#  13  cogs                     3000 non-null   float64
# ...

# %%
combined['Date'] = pd.to_datetime(combined['Date'])
#Used to convert Date to DateTime datatype

# %%
combined.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
combined.Date.head()
# Out:
# 0   2019-02-20
# 1   2019-02-06
# 2   2019-03-09
# 3   2019-01-15
# 4   2019-03-11
# Name: Date, dtype: datetime64[ns]

# %%
combined['Time'] = pd.to_datetime(combined['Time'])
#Used to convert Time to DateTime datatype

# %%
combined.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date                Time  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20 2022-08-10 13:27:00
# 1      5212.8         4   1042.56   21893.76 2019-02-06 2022-08-10 18:07:00
# 2      9183.6         4   1836.72   38571.12 2019-03-09 2022-08-10 17:03:00
# 3     33739.2         6  10121.76  212556.96 2019-01-15 2022-08-10 16:19:00
# 4     14508.0         2   1450.80   30466.80 2019-03-11 2022-08-10 15:30:00
#
# ...

# %%
combined.Time.head()
# Out:
# 0   2022-08-10 13:27:00
# 1   2022-08-10 18:07:00
# 2   2022-08-10 17:03:00
# 3   2022-08-10 16:19:00
# 4   2022-08-10 15:30:00
# Name: Time, dtype: datetime64[ns]

# %%
combined['Day'] = combined['Date'].dt.day

# %%
combined['Year'] = combined['Date'].dt.year

# %%
combined['Month'] = combined['Date'].dt.month

# %%
combined['Hour'] = combined['Time'].dt.hour

# %%
combined.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total  ...                Time Payment  \
# 0     19742.4         3   2961.36   62188.56  ... 2022-08-10 13:27:00    Card
# 1      5212.8         4   1042.56   21893.76  ... 2022-08-10 18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12  ... 2022-08-10 17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96  ... 2022-08-10 16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80  ... 2022-08-10 15:30:00    Epay
#
# ...

# %%
combined['Hour'].nunique()
# Out:
# 11

# %%
combined['Hour'].unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %%
categorical_columns = [col for col in combined.columns if combined[col].dtype == "object" ]
#Used to view all columns with DataType object.

# %%
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
combined['Invoice ID'].unique().tolist()
# Out:
# ['692-92-5582',
#  '351-62-0822',
#  '529-56-3974',
#  '299-46-1805',
#  '319-50-3348',
#  '371-85-5789',
#  '273-16-6619',
#  '649-29-6775',
#  '145-94-9061',
#  '871-79-8483',
#  '149-71-6266',
#  '640-49-2076',
#  '777-82-7220',
#  '280-35-5823',
#  '354-25-5821',
#  '132-32-9879',
#  '370-41-7321',
#  '727-46-3608',
#  '669-54-1719',
#  '616-24-2851',
#  '242-55-6721',
#  '347-34-2234',
#  '853-23-2453',
#  '109-28-2512',
#  '510-95-6347',
#  '847-38-7188',
#  '318-68-5053',
#  '152-08-9985',
#  '766-85-7061',
#  '733-01-9107',
#  '716-39-1409',
#  '479-26-8945',
#  '227-78-1148',
#  '291-32-1427',
#  '659-65-8956',
#  '378-24-2715',
#  '219-22-9386',
#  '268-27-6179',
#  '549-84-7482',
#  '191-10-6171',
#  '695-51-0018',
#  '590-83-4591',
#  '241-72-9525',
#  '262-47-2794',
#  '608-96-3517',
#  '279-74-2924',
#  '307-85-2293',
#  '743-04-1105',
#  '423-57-2993',
#  '548-46-9322',
#  '505-02-0892',
#  '316-55-4634',
#  '608-27-6295',
#  '414-12-7047',
#  '895-66-0685',
# ...

# %%
print("Total Number of unique values in the Invoice ID Column : {}". format(len(combined['Invoice ID'].unique().tolist())))
# Out:
# Total Number of unique values in the Invoice ID Column : 1000

# %%
combined['City'].unique().tolist()
#Used to get City column to a list
# Out:
# ['Abuja', 'Lagos', 'Port Harcourt']

# %%
print("Total Number of unique values in the City Column : {}". format(len(combined['City'].unique().tolist())))
# Out:
# Total Number of unique values in the City Column : 3

# %%
combined['Customer type'].unique().tolist()
#Used to get Customer type column to a list
# Out:
# ['Member', 'Normal']

# %%
print("Total Number of unique values in the Customer type Column : {}". format(len(combined['Customer type'].unique().tolist())))
# Out:
# Total Number of unique values in the Customer type Column : 2

# %%
combined['Gender'].unique().tolist()
# Out:
# ['Female', 'Male']

# %%
print("Total Number of unique values in the Gender Column : {}". format(len(combined['Gender'].unique().tolist())))
# Out:
# Total Number of unique values in the Gender Column : 2

# %%
combined['Product line'].unique().tolist()
# Out:
# ['Food and beverages',
#  'Fashion accessories',
#  'Electronic accessories',
#  'Sports and travel',
#  'Home and lifestyle',
#  'Health and beauty']

# %%
print("Total Number of unique values in the Product line Column : {}". format(len(combined['Product line'].unique().tolist())))
# Out:
# Total Number of unique values in the Product line Column : 6

# %%
combined['Payment'].unique().tolist()
# Out:
# ['Card', 'Epay', 'Cash']

# %%
print("Total Number of unique values in the Payment Column : {}". format(len(combined['Payment'].unique().tolist())))
# Out:
# Total Number of unique values in the Payment Column : 3

# %%
combined['Invoice ID'].value_counts()
#Used the count the values of Invoice ID
# Out:
# 692-92-5582    3
# 849-09-3807    3
# 324-92-3863    3
# 593-08-5916    3
# 558-60-5016    3
#               ..
# 365-64-0515    3
# 252-56-2699    3
# 829-34-3910    3
# 656-95-9349    3
# 233-67-5758    3
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
combined['City'].value_counts()
# Out:
# Lagos            1020
# Abuja             996
# Port Harcourt     984
# Name: City, dtype: int64

# %%
combined['Customer type'].value_counts()
# Out:
# Member    1503
# Normal    1497
# Name: Customer type, dtype: int64

# %%
combined['Gender'].value_counts()
# Out:
# Female    1503
# Male      1497
# Name: Gender, dtype: int64

# %%
combined['Product line'].value_counts()
# Out:
# Fashion accessories       534
# Food and beverages        522
# Electronic accessories    510
# Sports and travel         498
# Home and lifestyle        480
# Health and beauty         456
# Name: Product line, dtype: int64

# %%
combined['Payment'].value_counts()
# Out:
# Epay    1035
# Cash    1032
# Card     933
# Name: Payment, dtype: int64

# %%
cities = combined.groupby('City')
#Used to make the City column a groupby DataFrame

# %%
cities

# %%
cities.agg({'gross income' : 'sum'})
# Out:
#                gross income
# City
# Abuja            5461594.56
# Lagos            5461733.34
# Port Harcourt    5686390.62

# %% [markdown]
# Port Harcourt has the highest gross income sum

# %%
cities.agg({'Unit price' : 'max'})
# Out:
#                Unit price
# City
# Abuja             35985.6
# Lagos             35938.8
# Port Harcourt     35985.6

# %%
ax = sns.countplot(x = 'Branch', data = combined)
#Used to visualize the Branch column from the data provided

# %%
ax = sns.countplot(x = 'Payment', data = combined)
#Used to visualize the Payment column from the data provided

# %%
ax = sns.countplot(x = 'City', data = combined)
#Used to visualize the City column from the data provided

# %%
ax = sns.countplot(y = 'Product line', data = combined)

# %%
ax = sns.countplot(y = 'Product line', hue = 'Payment', data = combined)

# %%
ax = sns.countplot(y = 'Payment', hue = 'Branch', data = combined)

# %%
ax = sns.boxplot(y = 'Rating', x = 'Branch', data = combined)

# %%
sns.catplot(x='Product line', y = 'Quantity', data=combined, hue = 'Gender', aspect = 4)
#Used 'aspect' to broaden the visulization

# %%
sns.catplot(x='Product line', y = 'Total', data=combined, hue = 'Gender', aspect = 4)

# %% [markdown]
# The above chart displays the gender which uses a product more or less.

# %%
sns.catplot(x='Product line', y = 'Quantity', data=combined, aspect = 4, kind = 'point')
plt.show()

# %%
sns.catplot(x='Product line', y = 'Unit price', data=combined, aspect = 4, kind = 'point')
plt.show()

# %% [markdown]
# The chart per gross income looks good but there is a fall in fashion accesssories.
# <br>
# The chart per unit price also looks good but there is a fall in electronic accessories

# %%
sns.catplot(x='Product line', y = 'Quantity', data=combined, hue = 'Gender', aspect = 4, kind = 'point')

# %% [markdown]
# From this chart, it is glaring that females use more of these products per quantity.

# %%
sns.catplot(x='Product line', y = 'Unit price', data=combined, hue = 'Gender', aspect = 4, kind = 'point')

# %% [markdown]
# From this chart, it is glaring that males use more of these products per unit price.

# %%
sns.catplot(x='Product line', y = 'gross income', data=combined, hue = 'Gender', aspect = 4, kind = 'point')

# %% [markdown]
# This shows the gender from which the company derives most of its gross income from. I recommend this particular gender be seriously targeted before setting the market to attract the other gender

# %%
ax = sns.histplot(y = 'Product line', hue = 'Payment', data = combined)

# %%
ax = sns.histplot(y = 'Payment', hue = 'Branch', data = combined)

# %% [markdown]
# I have discovered tremendous insights from the analysis taken above. Though not not limited to my analysis for there is still much to be discovered on this company's product.
# I would link my findings and methods via the ReadMe folder I would attach to this analysis.
